# %% [markdown]
# <a href="https://colab.research.google.com/github/Keshavanand20/Machine_Learning/blob/main/FIFA_Data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as BS
import re

# %% [markdown]
# link = "https://sofifa.com/players?offset=1"
# ---
# the number after "offset=" is the page number so we have to scrape the data from 10 pages
#
# The things that we need to do are
# 1. scrape the data
# 2. Data Exploration, Data cleaning, Data Manipulation
# 3. Convert it into data frame
# 4. Perform the analysis (Exploratory Data Analysis(EDA))

# %%
url = "https://sofifa.com/players?offset=1"
req = requests.get(url)
req
# Out:
# <Response [403]>

# %% [markdown]
# So becausewe didn't the right response

# %%
soup_file = "/content/soup.html"
soup = pd.read_html(soup_file)
soup
# Out:
# [    Unnamed: 0                     Name  Age  Overall rating  Potential  \
#  0          NaN            E. Eze CAM LW   26              81         83
#  1          NaN      J. Enciso CAM LM RM   20              73         84
#  2          NaN      M. Rogers CAM LM RM   21              81         85
#  3          NaN        K. Nakamura LM LW   23              76         81
#  4          NaN         T. Dibling RW RM   18              73         84
#  5          NaN                 Jefté LB   20              71         79
#  6          NaN           V. Boniface ST   23              82         87
#  7          NaN          M. Fofana LM LW   19              76         85
#  8          NaN      C. Harder ST CAM LW   19              71         86
#  9          NaN             Nico Paz CAM   19              76         86
#  10         NaN      B. El Khannouss CAM   20              76         84
#  11         NaN     J. Oosterwolde LB CB   23              76         83
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3794955972.py in <cell line: 0>()
# ----> 1 soup.type
#
# AttributeError: 'list' object has no attribute 'type'

# %%
soup_2d = soup.reshape(-1,soup.shape[-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1917159999.py in <cell line: 0>()
# ----> 1 soup_2d = soup.reshape(-1,soup.shape[-1])
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
soup_df = soup[0]
display(soup_df.head())
# Out:
#    Unnamed: 0                 Name  Age  Overall rating  Potential  \
# 0         NaN        E. Eze CAM LW   26              81         83
# 1         NaN  J. Enciso CAM LM RM   20              73         84
# 2         NaN  M. Rogers CAM LM RM   21              81         85
# 3         NaN    K. Nakamura LM LW   23              76         81
# 4         NaN     T. Dibling RW RM   18              73         84
#
#                      Team & Contract   Value  Wage  Total stats  Unnamed: 9
# 0         Crystal Palace 2020 ~ 2027    €32M  €95K         2075         NaN
# 1  Ipswich Town Jun 30, 2025 On loan   €6.5M  €43K         1782         NaN
# 2            Aston Villa 2024 ~ 2030  €37.5M  €88K         2107         NaN
# 3         Stade de Reims 2023 ~ 2028  €11.5M  €20K         1924         NaN
# 4            Southampton 2023 ~ 2026   €6.5M  €30K         1825         NaN

# %%
soup.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1112121352.py in <cell line: 0>()
# ----> 1 soup.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
soup_df = pd.DataFrame(soup)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-299761649.py in <cell line: 0>()
# ----> 1 soup_df = pd.DataFrame(soup)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     865                     )
#     866                 else:
# --> 867                     mgr = ndarray_to_mgr(
#     868                         data,
#     869                         index,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     317         # by definition an array here
#     318         # the dtypes will be coerced to a single dtype
# --> 319         values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#     320
#     321     if dtype is not None and values.dtype != dtype:
#
# ...
